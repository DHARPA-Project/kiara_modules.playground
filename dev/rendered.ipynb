# %%
import kiara
from kiara.interfaces.python_api import Step
from kiara.utils.jupyter import graph_to_image

# %% [markdown]
# # Table of contents
# * [Assembling the workflow](#assembly)
#     * [Creating the steps of the workflow](#creating_steps)
#         * [Execution stage: 1](#execution_stage_1)
#             - [Step: ``read_files_in_folder``](#execution_stage_1_read_files_in_folder)
#         * [Execution stage: 2](#execution_stage_2)
#             - [Step: ``create_table_from_csvs``](#execution_stage_1_create_table_from_csvs)
#         * [Execution stage: 3](#execution_stage_3)
#             - [Step: ``extract_date_from_file_name``](#execution_stage_1_extract_date_from_file_name)
#             - [Step: ``extract_ref_from_file_name``](#execution_stage_2_extract_ref_from_file_name)
#         * [Execution stage: 4](#execution_stage_4)
#             - [Step: ``lookup_publication_name``](#execution_stage_1_lookup_publication_name)
#             - [Step: ``create_date_range_filter``](#execution_stage_2_create_date_range_filter)
#         * [Execution stage: 5](#execution_stage_5)
#             - [Step: ``merged_table``](#execution_stage_1_merged_table)
#         * [Execution stage: 6](#execution_stage_6)
#             - [Step: ``filtered_table``](#execution_stage_1_filtered_table)
#         * [Execution stage: 7](#execution_stage_7)
#             - [Step: ``tokenize_text_corpus``](#execution_stage_1_tokenize_text_corpus)
#         * [Execution stage: 8](#execution_stage_8)
#             - [Step: ``remove_stopwords``](#execution_stage_1_remove_stopwords)
#         * [Execution stage: 9](#execution_stage_9)
#             - [Step: ``lemmatize_corpus``](#execution_stage_1_lemmatize_corpus)
#         * [Execution stage: 10](#execution_stage_10)
#             - [Step: ``generate_lda``](#execution_stage_1_generate_lda)
#     * [Connecting the workflow steps](#connecting_steps)
# * [Workflow information](#workflow_info)
# * [Workflow results](#workflow_results)
#     - [Step: ``read_files_in_folder``](#output_stage_1_read_files_in_folder)
#     - [Step: ``create_table_from_csvs``](#output_stage_1_create_table_from_csvs)
#     - [Step: ``extract_date_from_file_name``](#output_stage_1_extract_date_from_file_name)
#     - [Step: ``extract_ref_from_file_name``](#output_stage_2_extract_ref_from_file_name)
#     - [Step: ``lookup_publication_name``](#output_stage_1_lookup_publication_name)
#     - [Step: ``create_date_range_filter``](#output_stage_2_create_date_range_filter)
#     - [Step: ``merged_table``](#output_stage_1_merged_table)
#     - [Step: ``filtered_table``](#output_stage_1_filtered_table)
#     - [Step: ``tokenize_text_corpus``](#output_stage_1_tokenize_text_corpus)
#     - [Step: ``remove_stopwords``](#output_stage_1_remove_stopwords)
#     - [Step: ``lemmatize_corpus``](#output_stage_1_lemmatize_corpus)
#     - [Step: ``generate_lda``](#output_stage_1_generate_lda)

# %% [markdown]
# # Assembling the workflow <a class="anchor" id="assembly"></a>
#
# The first step in the creation of our workflow is to create the individual steps from the available *kiara* modules.
#
# A list of available modules and their aliases can be found here: TODO
#
# ## Creating the steps of the workflow <a class="anchor" id="creating_steps"></a>

# %% [markdown]
# ### Execution stage: 1 <a class="anchor" id="execution_stage_1"></a>

# %% [markdown]
# #### Creating step: ``read_files_in_folder`` <a class="anchor" id="execution_stage_1_read_files_in_folder"></a>

# %%
step_read_files_in_folder = Step("onboarding.folder.import", step_id="read_files_in_folder")
step_read_files_in_folder.info
# Out:
#
#   Description     Import a local folder and its metadata.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616297.7821083-669766;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616297.782125-44211;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616297.7821388-734813;https://dharpa.org/kiara_modules.core/modules_list.html#onboardingfolderimport\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616297.7821522-144195;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/onboarding/folder.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    ImportFolderModule
#                     module_name   kiara_modules.core.onboarding.folder
#                     full_name     kiara_modules.core.onboarding.folder.ImportFolderModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {},
#                     "source_is_immutable": false
#                   }
#
#   Inputs
#                     Field name       Type     Description      Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     path             string   The path to      yes        -- no default
#                                               the folder.                 --
#                     included_files   list     A list of        no         -- no default
#                                               strings,                    --
#                                               include all
#                                               files where
#                                               the filename
#                                               ends with that
#                                               string.
#                     excluded_dirs    list     A list of        no         -- no default
#                                               strings,                    --
#                                               exclude all
#                                               folders whose
#                                               name ends with
#                                               that string.
#
#
#   Outputs
#                     Field name    Type          Description
#                    ───────────────────────────────────────────────────────────────────────
#                     file_bundle   file_bundle   The collection of files contained in the
#                                                 bundle.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       path = inputs.get_value_data("path")
#
#                       included_files = inputs.get_value_data("included_files")
#                       excluded_dirs = inputs.get_value_data("excluded_dirs")
#
#                       import_config = FolderImportConfig(
#                           include_files=included_files, exclude_dirs=excluded_dirs
#                       )
#
#                       bundle = FileBundleMetadata.import_folder(
#                           source=path, import_config=import_config
#                       )
#
#                       outputs.set_values(file_bundle=bundle)

# %% [markdown]
# ### Execution stage: 2 <a class="anchor" id="execution_stage_2"></a>

# %% [markdown]
# #### Creating step: ``create_table_from_csvs`` <a class="anchor" id="execution_stage_1_create_table_from_csvs"></a>

# %%
step_create_table_from_csvs_config = {'columns': ['id', 'rel_path', 'file_name', 'content']}
step_create_table_from_csvs = Step(
    "table.from_file_bundle",
    module_config=step_create_table_from_csvs_config,
    step_id="create_table_from_csvs")
step_create_table_from_csvs.info
# Out:
#
#   Description     Create a table from a 'file_bundle'.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616297.8641543-303985;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616297.8641768-8945;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616297.8642063-128719;https://dharpa.org/kiara_modules.core/modules_list.html#tablefrom_file_bundle\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616297.8642206-375371;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/table/__init__.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    CreateTableFromTextFilesModule
#                     module_name   kiara_modules.core.table
#                     full_name     kiara_modules.core.table.CreateTableFromTextFilesModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {},
#                     "columns": [
#                       "id",
#                       "rel_path",
#                       "file_name",
#                       "content"
#                     ]
#                   }
#
#   Inputs
#                     Field name   Type          Description      Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     files        file_bundle   The files to     yes        -- no default
#                                                use for the                 --
#                                                table.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     table        table   A table with the index column 'id', a column
#                                          'rel_path' that indicates the relative path of
#                                          the file in the bundle, and a column 'content'
#                                          that holds the (text) content of every file.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       bundle: FileBundleMetadata = inputs.get_value_data("files")
#
#                       columns = self.get_config_value("columns")
#                       if not columns:
#                           columns = DEFAULT_COLUMNS
#
#                       if "content" in columns:
#                           file_dict = bundle.read_text_file_contents()
#                       else:
#                           file_dict = {}
#                           for rel_path in bundle.included_files.keys():
#                               file_dict = None  # type: ignore
#
#                       tabular: typing.Dict] = {}
#                       for column in columns:
#                           for index, rel_path in enumerate(sorted(file_dict.keys())):
#
#                               if column == "content":
#                                   value: typing.Any = file_dict
#                               elif column == "id":
#                                   value = index
#                               elif column == "rel_path":
#                                   value = rel_path
#                               else:
#                                   file_model = bundle.included_files
#                                   value = getattr(file_model, column)
#
#                               tabular.setdefault(column, []).append(value)
#
#                       table = pa.Table.from_pydict(tabular)
#
#                       outputs.set_value("table", table)

# %% [markdown]
# ### Execution stage: 3 <a class="anchor" id="execution_stage_3"></a>

# %% [markdown]
# #### Creating step: ``extract_date_from_file_name`` <a class="anchor" id="execution_stage_1_extract_date_from_file_name"></a>

# %%
step_extract_date_from_file_name_config = {'module_type': 'date.extract_from_string'}
step_extract_date_from_file_name = Step(
    "array.map",
    module_config=step_extract_date_from_file_name_config,
    step_id="extract_date_from_file_name")
step_extract_date_from_file_name.info
# Out:
#
#   Description     Map a list of values into another list of values.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding, array
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616297.9284298-708367;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616297.9284544-579518;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616297.928486-304874;https://dharpa.org/kiara_modules.core/modules_list.html#arraymap\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616297.9285035-546267;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/array/__init__.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    MapModule
#                     module_name   kiara_modules.core.array
#                     full_name     kiara_modules.core.array.MapModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {},
#                     "module_type": "date.extract_from_string",
#                     "module_config": {},
#                     "input_name": null,
#                     "output_name": null
#                   }
#
#   Inputs
#                     Field name   Type    Description          Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   The array            yes        -- no default --
#                                          containing the
#                                          values the filter
#                                          is applied on.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   An array of equal length to the input array,
#                                          containing the 'mapped' values.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       input_array: pa.Array = inputs.get_value_data("array")
#
#                       init_data: typing.Dict = {}
#                       for input_name in self.input_schemas.keys():
#                           if input_name in ["array", self.module_input_name]:
#                               continue
#
#                           init_data = inputs.get_value_obj(input_name)
#
#                       result_list = map_with_module(
#                           input_array,
#                           module_input_name=self.module_input_name,
#                           module_obj=self.child_module,
#                           init_data=init_data,
#                           module_output_name=self.module_output_name,
#                       )
#                       outputs.set_value("array", pa.array(result_list))

# %% [markdown]
# #### Creating step: ``extract_ref_from_file_name`` <a class="anchor" id="execution_stage_2_extract_ref_from_file_name"></a>

# %%
step_extract_ref_from_file_name_config = {'module_type': 'string.match_regex', 'module_config': {'regex': '(\\w+\\d+)_\\d{4}-\\d{2}-\\d{2}_', 'only_first_match': True}}
step_extract_ref_from_file_name = Step(
    "array.map",
    module_config=step_extract_ref_from_file_name_config,
    step_id="extract_ref_from_file_name")
step_extract_ref_from_file_name.info
# Out:
#
#   Description     Map a list of values into another list of values.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding, array
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616297.9902391-855191;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616297.9902587-906543;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616297.9902651-942929;https://dharpa.org/kiara_modules.core/modules_list.html#arraymap\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616297.9902713-835505;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/array/__init__.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    MapModule
#                     module_name   kiara_modules.core.array
#                     full_name     kiara_modules.core.array.MapModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {},
#                     "module_type": "string.match_regex",
#                     "module_config": {
#                       "regex": "(\\w+\\d+)_\\d{4}-\\d{2}-\\d{2}_",
#                       "only_first_match": true
#                     },
#                     "input_name": null,
#                     "output_name": null
#                   }
#
#   Inputs
#                     Field name   Type    Description          Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   The array            yes        -- no default --
#                                          containing the
#                                          values the filter
#                                          is applied on.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   An array of equal length to the input array,
#                                          containing the 'mapped' values.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       input_array: pa.Array = inputs.get_value_data("array")
#
#                       init_data: typing.Dict = {}
#                       for input_name in self.input_schemas.keys():
#                           if input_name in ["array", self.module_input_name]:
#                               continue
#
#                           init_data = inputs.get_value_obj(input_name)
#
#                       result_list = map_with_module(
#                           input_array,
#                           module_input_name=self.module_input_name,
#                           module_obj=self.child_module,
#                           init_data=init_data,
#                           module_output_name=self.module_output_name,
#                       )
#                       outputs.set_value("array", pa.array(result_list))

# %% [markdown]
# ### Execution stage: 4 <a class="anchor" id="execution_stage_4"></a>

# %% [markdown]
# #### Creating step: ``lookup_publication_name`` <a class="anchor" id="execution_stage_1_lookup_publication_name"></a>

# %%
step_lookup_publication_name_config = {'module_type': 'string.replace', 'module_config': {'replacement_map': {'sn85066408': "L\\'Italia", '2012271201': 'Cronaca Sovversiva'}}}
step_lookup_publication_name = Step(
    "array.map",
    module_config=step_lookup_publication_name_config,
    step_id="lookup_publication_name")
step_lookup_publication_name.info
# Out:
#
#   Description     Map a list of values into another list of values.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding, array
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616298.0543926-238315;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616298.0544138-197085;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616298.05442-226371;https://dharpa.org/kiara_modules.core/modules_list.html#arraymap\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616298.0544262-458550;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/array/__init__.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    MapModule
#                     module_name   kiara_modules.core.array
#                     full_name     kiara_modules.core.array.MapModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {},
#                     "module_type": "string.replace",
#                     "module_config": {
#                       "replacement_map": {
#                         "sn85066408": "L\\'Italia",
#                         "2012271201": "Cronaca Sovversiva"
#                       }
#                     },
#                     "input_name": null,
#                     "output_name": null
#                   }
#
#   Inputs
#                     Field name   Type    Description          Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   The array            yes        -- no default --
#                                          containing the
#                                          values the filter
#                                          is applied on.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   An array of equal length to the input array,
#                                          containing the 'mapped' values.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       input_array: pa.Array = inputs.get_value_data("array")
#
#                       init_data: typing.Dict = {}
#                       for input_name in self.input_schemas.keys():
#                           if input_name in ["array", self.module_input_name]:
#                               continue
#
#                           init_data = inputs.get_value_obj(input_name)
#
#                       result_list = map_with_module(
#                           input_array,
#                           module_input_name=self.module_input_name,
#                           module_obj=self.child_module,
#                           init_data=init_data,
#                           module_output_name=self.module_output_name,
#                       )
#                       outputs.set_value("array", pa.array(result_list))

# %% [markdown]
# #### Creating step: ``create_date_range_filter`` <a class="anchor" id="execution_stage_2_create_date_range_filter"></a>

# %%
step_create_date_range_filter_config = {'module_type': 'date.range_check', 'input_name': 'date'}
step_create_date_range_filter = Step(
    "array.map",
    module_config=step_create_date_range_filter_config,
    step_id="create_date_range_filter")
step_create_date_range_filter.info
# Out:
#
#   Description     Map a list of values into another list of values.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding, array
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616298.1188095-311421;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616298.1188293-15852;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616298.1188352-77352;https://dharpa.org/kiara_modules.core/modules_list.html#arraymap\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616298.1188414-447272;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/array/__init__.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    MapModule
#                     module_name   kiara_modules.core.array
#                     full_name     kiara_modules.core.array.MapModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {},
#                     "module_type": "date.range_check",
#                     "module_config": {},
#                     "input_name": "date",
#                     "output_name": null
#                   }
#
#   Inputs
#                     Field name   Type    Description          Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   The array            yes        -- no default --
#                                          containing the
#                                          values the filter
#                                          is applied on.
#                     earliest     date    The earliest date    no         -- no default --
#                                          that is allowed.
#                     latest       date    The latest date      no         -- no default --
#                                          that is allowed.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   An array of equal length to the input array,
#                                          containing the 'mapped' values.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       input_array: pa.Array = inputs.get_value_data("array")
#
#                       init_data: typing.Dict = {}
#                       for input_name in self.input_schemas.keys():
#                           if input_name in ["array", self.module_input_name]:
#                               continue
#
#                           init_data = inputs.get_value_obj(input_name)
#
#                       result_list = map_with_module(
#                           input_array,
#                           module_input_name=self.module_input_name,
#                           module_obj=self.child_module,
#                           init_data=init_data,
#                           module_output_name=self.module_output_name,
#                       )
#                       outputs.set_value("array", pa.array(result_list))

# %% [markdown]
# ### Execution stage: 5 <a class="anchor" id="execution_stage_5"></a>

# %% [markdown]
# #### Creating step: ``merged_table`` <a class="anchor" id="execution_stage_1_merged_table"></a>

# %%
step_merged_table = Step("table.merge", step_id="merged_table")
step_merged_table.info
# Out:
#
#   Description     Create a table from other tables and/or arrays.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding, array
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616298.183245-374055;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616298.183267-939713;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616298.18329-675256;https://dharpa.org/kiara_modules.core/modules_list.html#tablemerge\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616298.1832964-846827;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/table/__init__.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    MergeTableModule
#                     module_name   kiara_modules.core.table
#                     full_name     kiara_modules.core.table.MergeTableModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {}
#                   }
#
#   Inputs
#                     Field name   Type   Description           Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     sources      dict   The source tables     yes        -- no default --
#                                         and/or columns.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     table        table   The merged table, including all source tables
#                                          and columns.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       sources = inputs.get_value_data("sources")
#
#                       len_dict = {}
#                       arrays = []
#                       column_names = []
#                       for source_key, table_or_column in sources.items():
#
#                           if isinstance(table_or_column, pa.Table):
#                               rows = table_or_column.num_rows
#                               for name in table_or_column.schema.names:
#                                   column = table_or_column.column(name)
#                                   arrays.append(column)
#                                   column_names.append(name)
#
#                           elif isinstance(table_or_column, pa.Array):
#                               rows = len(table_or_column)
#                               arrays.append(table_or_column)
#                               column_names.append(source_key)
#                           else:
#                               raise KiaraProcessingException(
#                                   f"Can't merge table: invalid type
#                   '{type(table_or_column)}' for source '{source_key}'."
#                               )
#
#                           len_dict = rows
#
#                       all_rows = None
#                       for source_key, rows in len_dict.items():
#                           if all_rows is None:
#                               all_rows = rows
#                           else:
#                               if all_rows != rows:
#                                   all_rows = None
#                                   break
#
#                       if all_rows is None:
#                           len_str = ""
#                           for name, rows in len_dict.items():
#                               len_str = f" {name} ({rows})"
#
#                           raise KiaraProcessingException(
#                               f"Can't merge table, sources have different
#                   lengths:{len_str}"
#                           )
#
#                       table = pa.Table.from_arrays(arrays=arrays, names=column_names)
#
#                       outputs.set_value("table", table)

# %% [markdown]
# ### Execution stage: 6 <a class="anchor" id="execution_stage_6"></a>

# %% [markdown]
# #### Creating step: ``filtered_table`` <a class="anchor" id="execution_stage_1_filtered_table"></a>

# %%
step_filtered_table = Step("table.filter.with_mask", step_id="filtered_table")
step_filtered_table.info
# Out:
#
#   Description     Filter a table using a mask array.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding, array
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616298.242523-148206;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616298.2425416-563243;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616298.2425642-139577;https://dharpa.org/kiara_modules.core/modules_list.html#tablefilterwith_mask\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616298.2425776-608354;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/table/filter.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    CreateFilteredTableModule
#                     module_name   kiara_modules.core.table.filter
#                     full_name     kiara_modules.core.table.filter.CreateFilteredTableMod…
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {}
#                   }
#
#   Inputs
#                     Field name   Type    Description          Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     table        table   The table to         yes        -- no default --
#                                          filter.
#                     mask         array   An mask array of     yes        -- no default --
#                                          booleans of the
#                                          same length as the
#                                          table.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ──────────────────────────────────────────
#                     table        table   The filtered table.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       input_table: pa.Table = inputs.get_value_data("table")
#                       filter_array: pa.Array = inputs.get_value_data("mask")
#
#                       filtered = input_table.filter(filter_array)
#
#                       outputs.set_value("table", filtered)

# %% [markdown]
# ### Execution stage: 7 <a class="anchor" id="execution_stage_7"></a>

# %% [markdown]
# #### Creating step: ``tokenize_text_corpus`` <a class="anchor" id="execution_stage_1_tokenize_text_corpus"></a>

# %%
step_tokenize_text_corpus_config = {'module_type': 'language.tokens.tokenize_text', 'input_name': 'text'}
step_tokenize_text_corpus = Step(
    "array.map",
    module_config=step_tokenize_text_corpus_config,
    step_id="tokenize_text_corpus")
step_tokenize_text_corpus.info
# Out:
#
#   Description     Map a list of values into another list of values.
#
#   Origin
#                     Authors   Markus Binsteiner (markus.binsteiner@uni.lu)
#
#
#   Type context
#                     Tags         core, onboarding, array
#                     Labels       package: kiara_modules.core
#                     References   source_repo:
#                                  ]8;id=1624616298.3052132-2148;https://github.com/DHARPA-Project/kiara_modules.core\https://github.com/DHARPA-Project/kiara_modules.core]8;;\
#                                  documentation: ]8;id=1624616298.3052332-59815;https://dharpa.org/kiara_modules.core/\https://dharpa.org/kiara_modules.core/]8;;\
#                                  module_doc:
#                                  ]8;id=1624616298.3052392-509858;https://dharpa.org/kiara_modules.core/modules_list.html#arraymap\https://dharpa.org/kiara_modules.core/modules_list.html…]8;;\
#                                  source_url:
#                                  ]8;id=1624616298.3052456-438572;https://github.com/DHARPA-Project/kiara_modules.core/blob/main/src/kiara_modules/core/array/__init__.py\https://github.com/DHARPA-Project/kiara_modules.core/bl…]8;;\
#
#
#   Python class
#                     class_name    MapModule
#                     module_name   kiara_modules.core.array
#                     full_name     kiara_modules.core.array.MapModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {},
#                     "module_type": "language.tokens.tokenize_text",
#                     "module_config": {},
#                     "input_name": "text",
#                     "output_name": null
#                   }
#
#   Inputs
#                     Field name   Type    Description          Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   The array            yes        -- no default --
#                                          containing the
#                                          values the filter
#                                          is applied on.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     array        array   An array of equal length to the input array,
#                                          containing the 'mapped' values.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       input_array: pa.Array = inputs.get_value_data("array")
#
#                       init_data: typing.Dict = {}
#                       for input_name in self.input_schemas.keys():
#                           if input_name in ["array", self.module_input_name]:
#                               continue
#
#                           init_data = inputs.get_value_obj(input_name)
#
#                       result_list = map_with_module(
#                           input_array,
#                           module_input_name=self.module_input_name,
#                           module_obj=self.child_module,
#                           init_data=init_data,
#                           module_output_name=self.module_output_name,
#                       )
#                       outputs.set_value("array", pa.array(result_list))

# %% [markdown]
# ### Execution stage: 8 <a class="anchor" id="execution_stage_8"></a>

# %% [markdown]
# #### Creating step: ``remove_stopwords`` <a class="anchor" id="execution_stage_1_remove_stopwords"></a>

# %%
step_remove_stopwords = Step("language.tokens.remove_stopwords", step_id="remove_stopwords")
step_remove_stopwords.info
# Out:
#
#   Description     Remove stopwords from an array of token-lists.
#
#   Origin
#                     Authors
#
#
#   Type context
#
#
#   Python class
#                     class_name    RemoveStopwordsModule
#                     module_name   kiara_modules.language_processing.tokens
#                     full_name     kiara_modules.language_processing.tokens.RemoveStopwor…
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {}
#                   }
#
#   Inputs
#                     Field name        Type    Description      Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     token_lists       array   An array of      yes        -- no default
#                                               string lists                --
#                                               (a list of
#                                               tokens).
#                     languages         list    A list of        no         -- no default
#                                               language names              --
#                                               to use default
#                                               stopword lists
#                                               for.
#                     additional_sto…   list    A list of        no         -- no default
#                                               additional,                 --
#                                               custom
#                                               stopwords.
#
#
#   Outputs
#                     Field name   Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     token_list   array   An array of string lists, with the stopwords
#                                          removed.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       custom_stopwords = inputs.get_value_data("additional_stopwords")
#                       languages = inputs.get_value_data("languages")
#                       if isinstance(languages, str):
#                           languages =
#
#                       stopwords = set()
#                       if languages:
#                           for language in languages:
#                               if language not in get_stopwords().fileids():
#                                   raise KiaraProcessingException(
#                                       f"Invalid language: {language}. Available: {',
#                   '.join(get_stopwords().fileids())}."
#                                   )
#                               stopwords.update(get_stopwords().words(language))
#
#                       if custom_stopwords:
#                           stopwords.update(custom_stopwords)
#
#                       if not stopwords:
#                           outputs.set_value("token_list",
#                   inputs.get_value_obj("token_lists"))
#                           return
#
#                       token_lists = inputs.get_value_data("token_lists")
#
#                       if hasattr(token_lists, "to_pylist"):
#                           token_lists = token_lists.to_pylist()
#
#                       result = []
#                       for token_list in token_lists:
#
#                           cleaned_list =
#                           result.append(cleaned_list)
#
#                       outputs.set_value("token_list", pa.array(result))

# %% [markdown]
# ### Execution stage: 9 <a class="anchor" id="execution_stage_9"></a>

# %% [markdown]
# #### Creating step: ``lemmatize_corpus`` <a class="anchor" id="execution_stage_1_lemmatize_corpus"></a>

# %%
step_lemmatize_corpus = Step("language.lemmatize.tokens_array", step_id="lemmatize_corpus")
step_lemmatize_corpus.info
# Out:
#
#   Description     Lemmatize an array of token lists.
#
#   Origin
#                     Authors
#
#
#   Type context
#
#
#   Python class
#                     class_name    LemmatizeTokensArrayModule
#                     module_name   kiara_modules.language_processing.lemmatize
#                     full_name     kiara_modules.language_processing.lemmatize.LemmatizeT…
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {}
#                   }
#
#   Inputs
#                     Field name     Type    Description        Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     tokens_array   array   An array of        yes        -- no default --
#                                            lists of tokens.
#
#
#   Outputs
#                     Field name     Type    Description
#                    ────────────────────────────────────────────────────────────────
#                     tokens_array   array   An array of lists of lemmatized tokens.
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#
#                       tokens: pa.Array = inputs.get_value_data("tokens_array")
#
#                       # TODO: install this on demand?
#                       import it_core_news_sm
#
#                       it_nlp = it_core_news_sm.load(disable=["tagger", "parser", "ner"])
#
#                       class CustomTokenizer(DummyTokenizer):
#                           def __init__(self, vocab):
#                               self.vocab = vocab
#
#                           def __call__(self, words):
#                               return Doc(self.vocab, words=words)
#
#                       it_nlp.tokenizer = CustomTokenizer(it_nlp.vocab)
#                       result = []
#
#                       for doc in it_nlp.pipe(
#                           tokens.to_pylist(),
#                           batch_size=32,
#                           n_process=3,
#                           disable=["parser", "ner", "tagger"],
#                       ):
#                           result.append()
#
#                       outputs.set_value("tokens_array", pa.array(result))

# %% [markdown]
# ### Execution stage: 10 <a class="anchor" id="execution_stage_10"></a>

# %% [markdown]
# #### Creating step: ``generate_lda`` <a class="anchor" id="execution_stage_1_generate_lda"></a>

# %%
step_generate_lda = Step("language.lda.LDA", step_id="generate_lda")
step_generate_lda.info
# Out:
#
#   Description     Perform Latent Dirichlet Allocation on a tokenized corpus.
#
#   Origin
#                     Authors
#
#
#   Type context
#
#
#   Python class
#                     class_name    LDAModule
#                     module_name   kiara_modules.language_processing.lda
#                     full_name     kiara_modules.language_processing.lda.LDAModule
#
#
#   Configuration   {
#                     "constants": {},
#                     "defaults": {}
#                   }
#
#   Inputs
#                     Field name       Type      Description      Required   Default
#                    ───────────────────────────────────────────────────────────────────────
#                     tokens_array     array     The text         yes        -- no default
#                                                corpus.                     --
#                     num_topics       integer   The number of    no         7
#                                                topics.
#                     compute_coher…   boolean   Whether to       no         False
#                                                train the
#                                                model without
#                                                coherence
#                                                calculation.
#
#
#   Outputs
#                     Field name    Type    Description
#                    ───────────────────────────────────────────────────────────────────────
#                     topic_model   table   A table with 'topic_id' and 'words' columns
#                                           (also 'num_topics', if coherence calculation
#                                           was switched on).
#
#
#   Source code     def process(self, inputs: ValueSet, outputs: ValueSet) -> None:
#                       logging.getLogger("gensim").setLevel(logging.ERROR)
#                       tokens_array = inputs.get_value_data("tokens_array")
#                       tokens = tokens_array.to_pylist()
#                       num_topics = inputs.get_value_data("num_topics")
#
#                       compute_coherence = inputs.get_value_data("compute_coherence")
#                       id2word = corpora.Dictionary(tokens)
#                       corpus =
#
#                       model = gensim.models.ldamulticore.LdaMulticore(
#                           corpus, id2word=id2word, num_topics=num_topics, eval_every=None
#                       )
#                       topic_print_model = model.print_topics(num_words=30)
#
#                       if not compute_coherence:
#                           df = pd.DataFrame(topic_print_model, columns=["topic_id",
#                   "words"])
#                           # TODO: create table directly
#                           result = Table.from_pandas(df)
#                       else:
#                           result = self.compute_with_coherence(
#                               corpus=corpus, id2word=id2word, corpus_model=tokens
#                           )
#
#                       outputs.set_value("topic_model", result)

# %% [markdown]
# ## Connecting the workflow steps <a class="anchor" id="connecting_steps"></a>
#
# After we all steps are created, we need to wire them up to create our workflow structure. All step inputs that are not
# connected to other step outputs are considered user inputs, and, if their values are marked as 'required', must be set
# later in order for our workflow to run successfully.

# %% [markdown]
# #### Connecting inputs for: ``create_table_from_csvs``

# %%
step_create_table_from_csvs.input.files = step_read_files_in_folder.output.file_bundle

# %% [markdown]
# #### Connecting inputs for: ``extract_date_from_file_name``

# %%
step_extract_date_from_file_name.input.array = step_create_table_from_csvs.output.table.file_name

# %% [markdown]
# #### Connecting inputs for: ``extract_ref_from_file_name``

# %%
step_extract_ref_from_file_name.input.array = step_create_table_from_csvs.output.table.file_name

# %% [markdown]
# #### Connecting inputs for: ``lookup_publication_name``

# %%
step_lookup_publication_name.input.array = step_extract_ref_from_file_name.output.array

# %% [markdown]
# #### Connecting inputs for: ``create_date_range_filter``

# %%
step_create_date_range_filter.input.array = step_extract_date_from_file_name.output.array

# %% [markdown]
# #### Connecting inputs for: ``merged_table``

# %%
step_merged_table.input.sources = [
    step_create_table_from_csvs.output.table,
    step_extract_date_from_file_name.output.array,
    step_extract_ref_from_file_name.output.array,
    step_lookup_publication_name.output.array,
]

# %% [markdown]
# #### Connecting inputs for: ``filtered_table``

# %%
step_filtered_table.input.table = step_merged_table.output.table

# %%
step_filtered_table.input.mask = step_create_date_range_filter.output.array

# %% [markdown]
# #### Connecting inputs for: ``tokenize_text_corpus``

# %%
step_tokenize_text_corpus.input.array = step_filtered_table.output.table.content

# %% [markdown]
# #### Connecting inputs for: ``remove_stopwords``

# %%
step_remove_stopwords.input.token_lists = step_tokenize_text_corpus.output.array

# %% [markdown]
# #### Connecting inputs for: ``lemmatize_corpus``

# %%
step_lemmatize_corpus.input.tokens_array = step_remove_stopwords.output.token_list

# %% [markdown]
# #### Connecting inputs for: ``generate_lda``

# %%
step_generate_lda.input.tokens_array = step_lemmatize_corpus.output.tokens_array

# %% [markdown]
# # Workflow information <a class="anchor" id="workflow_info"></a>
#
# After our workflow is wired up, we look can look at its structure, and other properties.
# For that, we need to retrieve the dynamically assembled workflow object. We could do this from every one of the workflow steps,
# since they all share the same workflow:

# %%
workflow = step_generate_lda.workflow

# %% [markdown]
# ## Workflow execution graph
#
# Let's look at the current execution graph for our workflow:

# %%
graph_to_image(workflow.structure.execution_graph)

# %% [markdown]
# # Setting workflow inputs <a class="anchor" id="workflow_inputs"></a>
#
# The final step before running the workflow, is to set input values:

# %%
step_read_files_in_folder.input.path = "/home/markus/projects/dharpa/notebooks/TopicModelling/data_tm_workflow"
step_create_date_range_filter.input.earliest = "1919-01-01"
step_create_date_range_filter.input.latest = "2000-01-01"
step_remove_stopwords.input.languages = ['italian', 'german']
step_generate_lda.input.compute_coherence = True

# %% [markdown]
# # Workflow results <a class="anchor" id="workflow_results"></a>
#
# We don't need to explicitly run the workflow, since our workflow object is smart enough to process the required steps
# for the outputs we request. But we can do it nonetheless, because it helps us debug any issues there might be by printing
# out the current workflow state:

# %%
# workflow.process()
workflow
# Out:
# Pipeline state for: dynamic
#
# Status: INPUTS_READY
#
# Inputs / Outputs
#
#   ╭─ Inputs ──────────────────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   Field name         Type      Description         Required      Status       Ready   │
#   │  ───────────────────────────────────────────────────────────────────────────────────  │
#   │   generate_lda__n…   integer   The number of       no           -- set --      yes    │
#   │                                topics.                                                │
#   │   generate_lda__c…   boolean   Whether to train    no           -- set --      yes    │
#   │                                the model without                                      │
#   │                                coherence                                              │
#   │                                calculation.                                           │
#   │   read_files_in_f…   string    The path to the     yes          -- set --      yes    │
#   │                                folder.                                                │
#   │   read_files_in_f…   list      A list of           no         -- not set --    yes    │
#   │                                strings, include                                       │
#   │                                all files where                                        │
#   │                                the filename ends                                      │
#   │                                with that string.                                      │
#   │   read_files_in_f…   list      A list of           no         -- not set --    yes    │
#   │                                strings, exclude                                       │
#   │                                all folders whose                                      │
#   │                                name ends with                                         │
#   │                                that string.                                           │
#   │   remove_stopword…   list      A list of           no           -- set --      yes    │
#   │                                language names to                                      │
#   │                                use default                                            │
#   │                                stopword lists                                         │
#   │                                for.                                                   │
#   │   remove_stopword…   list      A list of           no         -- not set --    yes    │
#   │                                additional,                                            │
#   │                                custom stopwords.                                      │
#   │   create_date_ran…   date      The earliest date   no           -- set --      yes    │
#   │                                that is allowed.                                       │
#   │   create_date_ran…   date      The latest date     no           -- set --      yes    │
#   │                                that is allowed.                                       │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Outputs ─────────────────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   Field name         Type          Description         Required    Status     Ready   │
#   │  ───────────────────────────────────────────────────────────────────────────────────  │
#   │   generate_lda__t…   table         A table with        yes        -- set --    yes    │
#   │                                    'topic_id' and                                     │
#   │                                    'words' columns                                    │
#   │                                    (also                                              │
#   │                                    'num_topics', if                                   │
#   │                                    coherence                                          │
#   │                                    calculation was                                    │
#   │                                    switched on).                                      │
#   │   read_files_in_f…   file_bundle   The collection of   yes        -- set --    yes    │
#   │                                    files contained                                    │
#   │                                    in the bundle.                                     │
#   │   remove_stopword…   array         An array of         yes        -- set --    yes    │
#   │                                    string lists,                                      │
#   │                                    with the                                           │
#   │                                    stopwords                                          │
#   │                                    removed.                                           │
#   │   lookup_publicat…   array         An array of equal   yes        -- set --    yes    │
#   │                                    length to the                                      │
#   │                                    input array,                                       │
#   │                                    containing the                                     │
#   │                                    'mapped' values.                                   │
#   │   lemmatize_corpu…   array         An array of lists   yes        -- set --    yes    │
#   │                                    of lemmatized                                      │
#   │                                    tokens.                                            │
#   │   extract_ref_fro…   array         An array of equal   yes        -- set --    yes    │
#   │                                    length to the                                      │
#   │                                    input array,                                       │
#   │                                    containing the                                     │
#   │                                    'mapped' values.                                   │
#   │   create_date_ran…   array         An array of equal   yes        -- set --    yes    │
#   │                                    length to the                                      │
#   │                                    input array,                                       │
#   │                                    containing the                                     │
#   │                                    'mapped' values.                                   │
#   │   merged_table__t…   table         The merged table,   yes        -- set --    yes    │
#   │                                    including all                                      │
#   │                                    source tables and                                  │
#   │                                    columns.                                           │
#   │   extract_date_fr…   array         An array of equal   yes        -- set --    yes    │
#   │                                    length to the                                      │
#   │                                    input array,                                       │
#   │                                    containing the                                     │
#   │                                    'mapped' values.                                   │
#   │   tokenize_text_c…   array         An array of equal   yes        -- set --    yes    │
#   │                                    length to the                                      │
#   │                                    input array,                                       │
#   │                                    containing the                                     │
#   │                                    'mapped' values.                                   │
#   │   filtered_table_…   table         The filtered        yes        -- set --    yes    │
#   │                                    table.                                             │
#   │   create_table_fr…   table         A table with the    yes        -- set --    yes    │
#   │                                    index column                                       │
#   │                                    'id', a column                                     │
#   │                                    'rel_path' that                                    │
#   │                                    indicates the                                      │
#   │                                    relative path of                                   │
#   │                                    the file in the                                    │
#   │                                    bundle, and a                                      │
#   │                                    column 'content'                                   │
#   │                                    that holds the                                     │
#   │                                    (text) content of                                  │
#   │                                    every file.                                        │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#
# Steps
#
#   ╭─ Processing stage: 1 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      read_files_in_folder                                                  │
#   │  ────────────────────────────────────────────────────────────────────────────────     │
#   │   type          ]8;id=1624616299.111384-269985;https://dharpa.org/kiara_modules.core/\onboarding.folder.import]8;;\                                              │
#   │   status        INPUTS_READY                                                          │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        path (type: string)              -- set --                            │
#   │                 included_files (type: list)      -- not set (not required) --         │
#   │                 excluded_dirs (type: list)       -- not set (not required) --         │
#   │   outputs       file_bundle (type: file_bundle)  -- set --                            │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 2 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      create_table_from_csvs                                                │
#   │  ───────────────────────────────────────────────────────                              │
#   │   type          ]8;id=1624616299.1159074-604855;https://dharpa.org/kiara_modules.core/\table.from_file_bundle]8;;\                                                │
#   │   status        STALE                                                                 │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        files (type: file_bundle)  -- set --                                  │
#   │   outputs       table (type: table)        -- set --                                  │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 3 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      extract_ref_from_file_name                                            │
#   │  ─────────────────────────────────────────────────                                    │
#   │   type          ]8;id=1624616299.1195478-798897;https://dharpa.org/kiara_modules.core/\array.map]8;;\                                                             │
#   │   status        STALE                                                                 │
#   │   required      no                                                                    │
#   │   is pipeline   no                                                                    │
#   │   inputs        array (type: array)  -- set --                                        │
#   │   outputs       array (type: array)  -- set --                                        │
#   │                                                                                       │
#   │                                                                                       │
#   │   step_id:      extract_date_from_file_name                                           │
#   │  ─────────────────────────────────────────────────                                    │
#   │   type          ]8;id=1624616299.12291-609551;https://dharpa.org/kiara_modules.core/\array.map]8;;\                                                             │
#   │   status        STALE                                                                 │
#   │   required      no                                                                    │
#   │   is pipeline   no                                                                    │
#   │   inputs        array (type: array)  -- set --                                        │
#   │   outputs       array (type: array)  -- set --                                        │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 4 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      lookup_publication_name                                               │
#   │  ─────────────────────────────────────────────────                                    │
#   │   type          ]8;id=1624616299.1266274-415225;https://dharpa.org/kiara_modules.core/\array.map]8;;\                                                             │
#   │   status        STALE                                                                 │
#   │   required      no                                                                    │
#   │   is pipeline   no                                                                    │
#   │   inputs        array (type: array)  -- set --                                        │
#   │   outputs       array (type: array)  -- set --                                        │
#   │                                                                                       │
#   │                                                                                       │
#   │   step_id:      create_date_range_filter                                              │
#   │  ───────────────────────────────────────────────────                                  │
#   │   type          ]8;id=1624616299.1302905-333352;https://dharpa.org/kiara_modules.core/\array.map]8;;\                                                             │
#   │   status        STALE                                                                 │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        array (type: array)    -- set --                                      │
#   │                 earliest (type: date)  -- set --                                      │
#   │                 latest (type: date)    -- set --                                      │
#   │   outputs       array (type: array)    -- set --                                      │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 5 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      merged_table                                                          │
#   │  ──────────────────────────────────────────────────                                   │
#   │   type          ]8;id=1624616299.1348922-665435;https://dharpa.org/kiara_modules.core/\table.merge]8;;\                                                           │
#   │   status        STALE                                                                 │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        sources (type: dict)  -- set --                                       │
#   │   outputs       table (type: table)   -- set --                                       │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 6 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      filtered_table                                                        │
#   │  ─────────────────────────────────────────────────                                    │
#   │   type          ]8;id=1624616299.1387181-383597;https://dharpa.org/kiara_modules.core/\table.filter.with_mask]8;;\                                                │
#   │   status        STALE                                                                 │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        table (type: table)  -- set --                                        │
#   │                 mask (type: array)   -- set --                                        │
#   │   outputs       table (type: table)  -- set --                                        │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 7 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      tokenize_text_corpus                                                  │
#   │  ─────────────────────────────────────────────────                                    │
#   │   type          ]8;id=1624616299.1429594-174283;https://dharpa.org/kiara_modules.core/\array.map]8;;\                                                             │
#   │   status        STALE                                                                 │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        array (type: array)  -- set --                                        │
#   │   outputs       array (type: array)  -- set --                                        │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 8 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      remove_stopwords                                                      │
#   │  ──────────────────────────────────────────────────────────────────────────────────   │
#   │   type          language.tokens.remove_stopwords                                      │
#   │   status        STALE                                                                 │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        token_lists (type: array)          -- set --                          │
#   │                 languages (type: list)             -- set --                          │
#   │                 additional_stopwords (type: list)  -- not set (not required) --       │
#   │   outputs       token_list (type: array)           -- set --                          │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 9 ─────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      lemmatize_corpus                                                      │
#   │  ────────────────────────────────────────────────────────                             │
#   │   type          language.lemmatize.tokens_array                                       │
#   │   status        STALE                                                                 │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        tokens_array (type: array)  -- set --                                 │
#   │   outputs       tokens_array (type: array)  -- set --                                 │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯
#   ╭─ Processing stage: 10 ────────────────────────────────────────────────────────────────╮
#   │                                                                                       │
#   │   step_id:      generate_lda                                                          │
#   │  ───────────────────────────────────────────────────────────────                      │
#   │   type          language.lda.LDA                                                      │
#   │   status        STALE                                                                 │
#   │   required      yes                                                                   │
#   │   is pipeline   no                                                                    │
#   │   inputs        tokens_array (type: array)         -- set --                          │
#   │                 num_topics (type: integer)         -- set --                          │
#   │                 compute_coherence (type: boolean)  -- set --                          │
#   │   outputs       topic_model (type: table)          -- set --                          │
#   │                                                                                       │
#   ╰───────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### Outputs for step: ``read_files_in_folder`` <a class="anchor" id="outputs_stage_1_read_files_in_folder"></a>
#
# ### Output: ``file_bundle``
# #### Value metadata

# %%
step_read_files_in_folder.output.file_bundle.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            c0ef635f-4437-4f71-bf26-24ad6f4ee824                                      │
# │   type          file_bundle                                                               │
# │   desc          The collection of files contained in the bundle.                          │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_read_files_in_folder.output.file_bundle.data)
# Out:
#
#   FileBundle(name=data_tm_workflow)

# %% [markdown]
# ### Outputs for step: ``create_table_from_csvs`` <a class="anchor" id="outputs_stage_1_create_table_from_csvs"></a>
#
# ### Output: ``table``
# #### Value metadata

# %%
step_create_table_from_csvs.output.table.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            125f03bd-b28d-4058-b95a-938a47af69a5                                      │
# │   type          table                                                                     │
# │   desc          A table with the index column 'id', a column 'rel_path' that indicates    │
# │                 the relative path of the file in the bundle, and a column 'content'       │
# │                 that holds the (text) content of every file.                              │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_create_table_from_csvs.output.table.data)
# Out:
#
#
#     id    rel_path                   file_name                  content
#    ───────────────────────────────────────────────────────────────────────────────────────
#     0     2012271201_1903-06-06_e…   2012271201_1903-06-06_e…   """" NUMERO Ebdomadario
#                                                                 anàrchico propaganda
#                                                                 rivoluzionaria, redezt
#                                                                 miseria abea ...
#
#     1     2012271201_1903-06-13_e…   2012271201_1903-06-13_e…   Ebdomadario anarchico
#                                                                 propaganda
#                                                                 rivoluzionaria. XJt
#                                                                 redezt miserìs abeat
#                                                                 fortun ...
#
#     2     2012271201_1903-06-20_e…   2012271201_1903-06-20_e…   ANNO NUMERO VVER
#                                                                 Ebdomadario anarchico
#                                                                 propaganda
#                                                                 rivoluzionaria. redeat
#                                                                 miserìs ...
#
#     3     2012271201_1903-06-27_e…   2012271201_1903-06-27_e…   Ebdomadàrio anarchico
#                                                                 propaganda
#                                                                 rivoluzionaria. redeat
#                                                                 miseris aheat fortuna su
#                                                                 ...
#
#     4     2012271201_1903-07-04_e…   2012271201_1903-07-04_e…   NUMERO Ebdomadario
#                                                                 anarchico propaganda
#                                                                 rivoluzionaria. redeat
#                                                                 miseiis abeat for ...
#
#     5     2012271201_1903-07-25_e…   2012271201_1903-07-25_e…   ANNO KtJ SIERO
#                                                                 Ebdomadario anarchico
#                                                                 propaganda
#                                                                 rivoluzionaria. redest
#                                                                 miseris a ...
#
#     6     2012271201_1903-08-01_e…   2012271201_1903-08-01_e…   ANNO NUMEHO Ebdomadario
#                                                                 anarchico propaganda
#                                                                 rivoluzionaria. redeai
#                                                                 miserìs abet ...
#
#     7     2012271201_1903-08-08_e…   2012271201_1903-08-08_e…   Ciac vtj'y inn NUMERO
#                                                                 Ebdomadario anarchico
#                                                                 propaganda
#                                                                 rivoluzionaria. redeat mi
#                                                                 ...
#
#     8     2012271201_1903-08-15_e…   2012271201_1903-08-15_e…   NUMERO Ebdomadario
#                                                                 anarchico propaganda
#                                                                 rivoluzionaria, redest
#                                                                 miserò abeat fort ...
#
#     9     2012271201_1903-08-22_e…   2012271201_1903-08-22_e…   Ebdomadario anarchico
#                                                                 propaganda:
#                                                                 rivoluzionaria. rtdest
#                                                                 miscris abeat fortuna,
#                                                                 ...
#
#     10    2012271201_1903-08-29_e…   2012271201_1903-08-29_e…   SUMERO Ebdomadario
#                                                                 anarchico propaganda
#                                                                 rivoluzionaria. redesi
#                                                                 mtseris àbeai for ...
#
#     11    2012271201_1903-09-05_e…   2012271201_1903-09-05_e…   Ebdomadario anarchico
#                                                                 propaganda '-'-'--'
#                                                                 f.vtfim czpcrbis!
#                                                                 bbonamcr.t annuo per ...
#
#     12    2012271201_1903-09-12_e…   2012271201_1903-09-12_e…   ANNO NUMERO Ebdomadario
#                                                                 anarchico propaganda
#                                                                 rivoluzionaria. redeat
#                                                                 miseiis abea ...
#
#     13    2012271201_1903-09-19_e…   2012271201_1903-09-19_e…   ANNO NtLNJEKO SOVVERSIVA
#                                                                 Ebdomadario anarchico
#                                                                 propaganda
#                                                                 rivoluzionaria. redéat
#                                                                 ...
#
#     14    2012271201_1903-09-26_e…   2012271201_1903-09-26_e…   NUMERO Ebdomadario
#                                                                 anarchico propaganda
#                                                                 rivoluzionaria, redeai
#                                                                 miseris abeat for ...
#
#     15    2012271201_1903-10-03_e…   2012271201_1903-10-03_e…   ANNO NUMERO ....
#                                                                 Ebdomadario anarchico
#                                                                 propaganda rivoluzionaria
#                                                                 redesi mtseris  ...
#
#     ...   ...                        ...                        ...
#     755   2012271201_1918-02-02_e…   2012271201_1918-02-02_e…   This newspaper has
#                                                                 -objectión iling with the
#                                                                 Postmaster Lynn, and ANNO
#                                                                 XVI-Num.  ...
#
#     756   2012271201_1918-02-09_e…   2012271201_1918-02-09_e…   This newspaper has
#                                                                 objection
#                                                                 ANELITIESINGULTI
#                                                                 SETTIMANA DEL CALENDARIO
#                                                                 FEBBRAIO  ...
#
#     757   2012271201_1918-02-16_e…   2012271201_1918-02-16_e…   ThiS newspaper has
#                                                                 objection .'.. fi' -r?rrt
#                                                                 uni ikii. Arvu avi mini-
#                                                                 UTO-DA -FE ...
#
#     758   2012271201_1918-02-23_e…   2012271201_1918-02-23_e…   This newspaper has
#                                                                 objection (ìing with the
#                                                                 Postmasterof Lynn, and
#                                                                 ANNO XVI-Num  ...
#
#     759   2012271201_1918-03-02_e…   2012271201_1918-03-02_e…   Thìs newspaper has
#                                                                 objection ANNO XVI Num.
#                                                                 Colf acqua siamo.
#                                                                 reazione democratic ...
#
#     760   2012271201_1918-03-09_e…   2012271201_1918-03-09_e…   This newspapet, has
#                                                                 objection ANvO Nura.
#                                                                 .Hill mmmmmmm im.iLi.Ji
#                                                                 ANELITI SINGULT ...
#
#     761   2012271201_1918-03-16_e…   2012271201_1918-03-16_e…   This newspaper has
#                                                                 objection ANNO XVI Nummi
#                                                                 !.. -"T ricordo della
#                                                                 Comune Parigi  ...
#
#     762   2012271201_1918-03-23_e…   2012271201_1918-03-23_e…   This newspaper. has
#                                                                 bjèction ANNO XVI Num.
#                                                                 mSSCH J&ftiRsi HvE.
#                                                                 premer. mj-.'- n- ...
#
#     763   2012271201_1918-03-30_e…   2012271201_1918-03-30_e…   .ft .v.r This newspaper
#                                                                 has objection iUing with
#                                                                 the Postraaster Lynn, and
#                                                                 ANNO  ...
#
#     764   2012271201_1918-04-06_e…   2012271201_1918-04-06_e…   Tfcis iscwspaper has
#                                                                 obectioa ANìnO XVI Num.
#                                                                 Note Sovversiva STATI
#                                                                 UNITI. beUeve ...
#
#     765   2012271201_1918-04-13_e…   2012271201_1918-04-13_e…   oc. st. so; s!: Thìs
#                                                                 newspaper has objection
#                                                                 MAGGIO Albeggia sui cieli
#                                                                 foschi, t ...
#
#     766   2012271201_1918-04-20_e…   2012271201_1918-04-20_e…   This nefcaper fcas &jsc
#                                                                 Octoberth, tbcrcfore
#                                                                 enttitfed ncecstrasted
#                                                                 circolatìon. ...
#
#     767   2012271201_1918-06-06_e…   2012271201_1918-06-06_e…   ANNO XVI nxn JVI affogano
#                                                                 stringono laccio alla
#                                                                 gola colle convulse dalla
#                                                                 duplic ...
#
#     768   2012271201_1918-07-18_e…   2012271201_1918-07-18_e…   ANNO XVI LYNN, MASS.,
#                                                                 JULY Ith,ì Num.
#                                                                 Corrispondenze, lettere,
#                                                                 money orders debb ...
#
#     769   2012271201_1919-03-20_e…   2012271201_1919-03-20_e…   ANNO XVn No. ...und heute
#                                                                 geht eine neue Epoche der
#                                                                 eltgescliiGhte aus" cuore
#                                                                 de ...
#
#     770   2012271201_1919-05-01_e…   2012271201_1919-05-01_e…   ANNO XVn No. cose ora
#                                                                 Francia. Parigi
#                                                                 l'assoluzione Rao Villain
#                                                                 che nel alla gil ...

# %% [markdown]
# ### Outputs for step: ``extract_date_from_file_name`` <a class="anchor" id="outputs_stage_1_extract_date_from_file_name"></a>
#
# ### Output: ``array``
# #### Value metadata

# %%
step_extract_date_from_file_name.output.array.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            5a59072f-2d8e-40a7-a072-7c52887172ea                                      │
# │   type          array                                                                     │
# │   desc          An array of equal length to the input array, containing the 'mapped'      │
# │                 values.                                                                   │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_extract_date_from_file_name.output.array.data)
# Out:
#
#   <pyarrow.lib.TimestampArray object at 0x7fd456f9b940>
#   [
#     1903-06-06 00:00:00.000000,
#     1903-06-13 00:00:00.000000,
#     1903-06-20 00:00:00.000000,
#     1903-06-27 00:00:00.000000,
#     1903-07-04 00:00:00.000000,
#     1903-07-25 00:00:00.000000,
#     1903-08-01 00:00:00.000000,
#     1903-08-08 00:00:00.000000,
#     1903-08-15 00:00:00.000000,
#     1903-08-22 00:00:00.000000,
#     ...
#     1918-03-16 00:00:00.000000,
#     1918-03-23 00:00:00.000000,
#     1918-03-30 00:00:00.000000,
#     1918-04-06 00:00:00.000000,
#     1918-04-13 00:00:00.000000,
#     1918-04-20 00:00:00.000000,
#     1918-06-06 00:00:00.000000,
#     1918-07-18 00:00:00.000000,
#     1919-03-20 00:00:00.000000,
#     1919-05-01 00:00:00.000000
#   ]

# %% [markdown]
# ### Outputs for step: ``extract_ref_from_file_name`` <a class="anchor" id="outputs_stage_2_extract_ref_from_file_name"></a>
#
# ### Output: ``array``
# #### Value metadata

# %%
step_extract_ref_from_file_name.output.array.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            fcd92bf4-96fe-4984-a178-c3c259b78a29                                      │
# │   type          array                                                                     │
# │   desc          An array of equal length to the input array, containing the 'mapped'      │
# │                 values.                                                                   │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_extract_ref_from_file_name.output.array.data)
# Out:
#
#   <pyarrow.lib.StringArray object at 0x7fd45c5062e0>
#   [
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     ...
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201",
#     "2012271201"
#   ]

# %% [markdown]
# ### Outputs for step: ``lookup_publication_name`` <a class="anchor" id="outputs_stage_1_lookup_publication_name"></a>
#
# ### Output: ``array``
# #### Value metadata

# %%
step_lookup_publication_name.output.array.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            29c6e5b2-7081-49ca-8543-fe07940936df                                      │
# │   type          array                                                                     │
# │   desc          An array of equal length to the input array, containing the 'mapped'      │
# │                 values.                                                                   │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_lookup_publication_name.output.array.data)
# Out:
#
#   <pyarrow.lib.StringArray object at 0x7fd455d41e80>
#   [
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     ...
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva",
#     "Cronaca Sovversiva"
#   ]

# %% [markdown]
# ### Outputs for step: ``create_date_range_filter`` <a class="anchor" id="outputs_stage_2_create_date_range_filter"></a>
#
# ### Output: ``array``
# #### Value metadata

# %%
step_create_date_range_filter.output.array.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            5b8ecae9-46ac-429a-8add-033adb560a90                                      │
# │   type          array                                                                     │
# │   desc          An array of equal length to the input array, containing the 'mapped'      │
# │                 values.                                                                   │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_create_date_range_filter.output.array.data)
# Out:
#
#   <pyarrow.lib.BooleanArray object at 0x7fd455d410a0>
#   [
#     false,
#     false,
#     false,
#     false,
#     false,
#     false,
#     false,
#     false,
#     false,
#     false,
#     ...
#     false,
#     false,
#     false,
#     false,
#     false,
#     false,
#     false,
#     false,
#     true,
#     true
#   ]

# %% [markdown]
# ### Outputs for step: ``merged_table`` <a class="anchor" id="outputs_stage_1_merged_table"></a>
#
# ### Output: ``table``
# #### Value metadata

# %%
step_merged_table.output.table.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            c27206bd-0e3a-493e-8037-426e64125fa4                                      │
# │   type          table                                                                     │
# │   desc          The merged table, including all source tables and columns.                │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_merged_table.output.table.data)
# Out:
#
#
#     id    rel_path      file_name     content       extract_d…   extract_re…   lookup_pu…
#    ───────────────────────────────────────────────────────────────────────────────────────
#     0     2012271201…   2012271201…   """" NUMERO   1903-06-06   2012271201    Cronaca
#                                       Ebdomadario   00:00:00                   Sovversiva
#                                       anàrchico
#                                       propaganda
#                                       rivoluzion…
#                                       redezt
#                                       miseria
#                                       abea ...
#
#     1     2012271201…   2012271201…   Ebdomadario   1903-06-13   2012271201    Cronaca
#                                       anarchico     00:00:00                   Sovversiva
#                                       propaganda
#                                       rivoluzion…
#                                       XJt redezt
#                                       miserìs
#                                       abeat
#                                       fortun ...
#
#     2     2012271201…   2012271201…   ANNO NUMERO   1903-06-20   2012271201    Cronaca
#                                       VVER          00:00:00                   Sovversiva
#                                       Ebdomadario
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redeat
#                                       miserìs ...
#
#     3     2012271201…   2012271201…   Ebdomadàrio   1903-06-27   2012271201    Cronaca
#                                       anarchico     00:00:00                   Sovversiva
#                                       propaganda
#                                       rivoluzion…
#                                       redeat
#                                       miseris
#                                       aheat
#                                       fortuna su
#                                       ...
#
#     4     2012271201…   2012271201…   NUMERO        1903-07-04   2012271201    Cronaca
#                                       Ebdomadario   00:00:00                   Sovversiva
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redeat
#                                       miseiis
#                                       abeat for
#                                       ...
#
#     5     2012271201…   2012271201…   ANNO KtJ      1903-07-25   2012271201    Cronaca
#                                       SIERO         00:00:00                   Sovversiva
#                                       Ebdomadario
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redest
#                                       miseris a
#                                       ...
#
#     6     2012271201…   2012271201…   ANNO NUMEHO   1903-08-01   2012271201    Cronaca
#                                       Ebdomadario   00:00:00                   Sovversiva
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redeai
#                                       miserìs
#                                       abet ...
#
#     7     2012271201…   2012271201…   Ciac vtj'y    1903-08-08   2012271201    Cronaca
#                                       inn NUMERO    00:00:00                   Sovversiva
#                                       Ebdomadario
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redeat mi
#                                       ...
#
#     8     2012271201…   2012271201…   NUMERO        1903-08-15   2012271201    Cronaca
#                                       Ebdomadario   00:00:00                   Sovversiva
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redest
#                                       miserò
#                                       abeat fort
#                                       ...
#
#     9     2012271201…   2012271201…   Ebdomadario   1903-08-22   2012271201    Cronaca
#                                       anarchico     00:00:00                   Sovversiva
#                                       propaganda:
#                                       rivoluzion…
#                                       rtdest
#                                       miscris
#                                       abeat
#                                       fortuna,
#                                       ...
#
#     10    2012271201…   2012271201…   SUMERO        1903-08-29   2012271201    Cronaca
#                                       Ebdomadario   00:00:00                   Sovversiva
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redesi
#                                       mtseris
#                                       àbeai for
#                                       ...
#
#     11    2012271201…   2012271201…   Ebdomadario   1903-09-05   2012271201    Cronaca
#                                       anarchico     00:00:00                   Sovversiva
#                                       propaganda
#                                       '-'-'--'
#                                       f.vtfim
#                                       czpcrbis!
#                                       bbonamcr.t
#                                       annuo per
#                                       ...
#
#     12    2012271201…   2012271201…   ANNO NUMERO   1903-09-12   2012271201    Cronaca
#                                       Ebdomadario   00:00:00                   Sovversiva
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redeat
#                                       miseiis
#                                       abea ...
#
#     13    2012271201…   2012271201…   ANNO          1903-09-19   2012271201    Cronaca
#                                       NtLNJEKO      00:00:00                   Sovversiva
#                                       SOVVERSIVA
#                                       Ebdomadario
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redéat ...
#
#     14    2012271201…   2012271201…   NUMERO        1903-09-26   2012271201    Cronaca
#                                       Ebdomadario   00:00:00                   Sovversiva
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redeai
#                                       miseris
#                                       abeat for
#                                       ...
#
#     15    2012271201…   2012271201…   ANNO NUMERO   1903-10-03   2012271201    Cronaca
#                                       ....          00:00:00                   Sovversiva
#                                       Ebdomadario
#                                       anarchico
#                                       propaganda
#                                       rivoluzion…
#                                       redesi
#                                       mtseris
#                                       ...
#
#     ...   ...           ...           ...           ...          ...           ...
#     755   2012271201…   2012271201…   This          1918-02-02   2012271201    Cronaca
#                                       newspaper     00:00:00                   Sovversiva
#                                       has
#                                       -objectión
#                                       iling with
#                                       the
#                                       Postmaster
#                                       Lynn, and
#                                       ANNO
#                                       XVI-Num.
#                                       ...
#
#     756   2012271201…   2012271201…   This          1918-02-09   2012271201    Cronaca
#                                       newspaper     00:00:00                   Sovversiva
#                                       has
#                                       objection
#                                       ANELITIESI…
#                                       SETTIMANA
#                                       DEL
#                                       CALENDARIO
#                                       FEBBRAIO
#                                       ...
#
#     757   2012271201…   2012271201…   ThiS          1918-02-16   2012271201    Cronaca
#                                       newspaper     00:00:00                   Sovversiva
#                                       has
#                                       objection
#                                       .'.. fi'
#                                       -r?rrt uni
#                                       ikii. Arvu
#                                       avi mini-
#                                       UTO-DA -FE
#                                       ...
#
#     758   2012271201…   2012271201…   This          1918-02-23   2012271201    Cronaca
#                                       newspaper     00:00:00                   Sovversiva
#                                       has
#                                       objection
#                                       (ìing with
#                                       the
#                                       Postmaster…
#                                       Lynn, and
#                                       ANNO
#                                       XVI-Num
#                                       ...
#
#     759   2012271201…   2012271201…   Thìs          1918-03-02   2012271201    Cronaca
#                                       newspaper     00:00:00                   Sovversiva
#                                       has
#                                       objection
#                                       ANNO XVI
#                                       Num. Colf
#                                       acqua
#                                       siamo.
#                                       reazione
#                                       democratic
#                                       ...
#
#     760   2012271201…   2012271201…   This          1918-03-09   2012271201    Cronaca
#                                       newspapet,    00:00:00                   Sovversiva
#                                       has
#                                       objection
#                                       ANvO Nura.
#                                       .Hill
#                                       mmmmmmm
#                                       im.iLi.Ji
#                                       ANELITI
#                                       SINGULT ...
#
#     761   2012271201…   2012271201…   This          1918-03-16   2012271201    Cronaca
#                                       newspaper     00:00:00                   Sovversiva
#                                       has
#                                       objection
#                                       ANNO XVI
#                                       Nummi !..
#                                       -"T ricordo
#                                       della
#                                       Comune
#                                       Parigi  ...
#
#     762   2012271201…   2012271201…   This          1918-03-23   2012271201    Cronaca
#                                       newspaper.    00:00:00                   Sovversiva
#                                       has
#                                       bjèction
#                                       ANNO XVI
#                                       Num. mSSCH
#                                       J&ftiRsi
#                                       HvE.
#                                       premer.
#                                       mj-.'- n-
#                                       ...
#
#     763   2012271201…   2012271201…   .ft .v.r      1918-03-30   2012271201    Cronaca
#                                       This          00:00:00                   Sovversiva
#                                       newspaper
#                                       has
#                                       objection
#                                       iUing with
#                                       the
#                                       Postraaster
#                                       Lynn, and
#                                       ANNO  ...
#
#     764   2012271201…   2012271201…   Tfcis         1918-04-06   2012271201    Cronaca
#                                       iscwspaper    00:00:00                   Sovversiva
#                                       has
#                                       obectioa
#                                       ANìnO XVI
#                                       Num. Note
#                                       Sovversiva
#                                       STATI
#                                       UNITI.
#                                       beUeve ...
#
#     765   2012271201…   2012271201…   oc. st. so;   1918-04-13   2012271201    Cronaca
#                                       s!: Thìs      00:00:00                   Sovversiva
#                                       newspaper
#                                       has
#                                       objection
#                                       MAGGIO
#                                       Albeggia
#                                       sui cieli
#                                       foschi, t
#                                       ...
#
#     766   2012271201…   2012271201…   This          1918-04-20   2012271201    Cronaca
#                                       nefcaper      00:00:00                   Sovversiva
#                                       fcas &jsc
#                                       Octoberth,
#                                       tbcrcfore
#                                       enttitfed
#                                       ncecstrast…
#                                       circolatìo…
#                                       ...
#
#     767   2012271201…   2012271201…   ANNO XVI      1918-06-06   2012271201    Cronaca
#                                       nxn JVI       00:00:00                   Sovversiva
#                                       affogano
#                                       stringono
#                                       laccio alla
#                                       gola colle
#                                       convulse
#                                       dalla
#                                       duplic ...
#
#     768   2012271201…   2012271201…   ANNO XVI      1918-07-18   2012271201    Cronaca
#                                       LYNN,         00:00:00                   Sovversiva
#                                       MASS., JULY
#                                       Ith,ì Num.
#                                       Corrispond…
#                                       lettere,
#                                       money
#                                       orders debb
#                                       ...
#
#     769   2012271201…   2012271201…   ANNO XVn      1919-03-20   2012271201    Cronaca
#                                       No. ...und    00:00:00                   Sovversiva
#                                       heute geht
#                                       eine neue
#                                       Epoche der
#                                       eltgesclii…
#                                       aus" cuore
#                                       de ...
#
#     770   2012271201…   2012271201…   ANNO XVn      1919-05-01   2012271201    Cronaca
#                                       No. cose      00:00:00                   Sovversiva
#                                       ora
#                                       Francia.
#                                       Parigi
#                                       l'assoluzi…
#                                       Rao Villain
#                                       che nel
#                                       alla gil
#                                       ...

# %% [markdown]
# ### Outputs for step: ``filtered_table`` <a class="anchor" id="outputs_stage_1_filtered_table"></a>
#
# ### Output: ``table``
# #### Value metadata

# %%
step_filtered_table.output.table.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            a9a2200f-78d4-4e7a-9bbb-5c364d3917a4                                      │
# │   type          table                                                                     │
# │   desc          The filtered table.                                                       │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_filtered_table.output.table.data)
# Out:
#
#
#     id    rel_path      file_name     content       extract_d…   extract_re…   lookup_pu…
#    ───────────────────────────────────────────────────────────────────────────────────────
#     769   2012271201…   2012271201…   ANNO XVn      1919-03-20   2012271201    Cronaca
#                                       No. ...und    00:00:00                   Sovversiva
#                                       heute geht
#                                       eine neue
#                                       Epoche der
#                                       eltgesclii…
#                                       aus" cuore
#                                       de ...
#
#     770   2012271201…   2012271201…   ANNO XVn      1919-05-01   2012271201    Cronaca
#                                       No. cose      00:00:00                   Sovversiva
#                                       ora
#                                       Francia.
#                                       Parigi
#                                       l'assoluzi…
#                                       Rao Villain
#                                       che nel
#                                       alla gil
#                                       ...

# %% [markdown]
# ### Outputs for step: ``tokenize_text_corpus`` <a class="anchor" id="outputs_stage_1_tokenize_text_corpus"></a>
#
# ### Output: ``array``
# #### Value metadata

# %%
step_tokenize_text_corpus.output.array.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            b88979f3-9c9d-434d-9eeb-652ebe22ad4e                                      │
# │   type          array                                                                     │
# │   desc          An array of equal length to the input array, containing the 'mapped'      │
# │                 values.                                                                   │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_tokenize_text_corpus.output.array.data)
# Out:
#
#   <pyarrow.lib.ListArray object at 0x7fd4566f5940>
#   [
#     [
#       "anno",
#       "xvn",
#       "und",
#       "heute",
#       "geht",
#       "eine",
#       "neue",
#       "epoche",
#       "der",
#       "eltgescliighte",
#       ...
#       "giogo",
#       "dei",
#       "nuovi",
#       "mandriani",
#       "che",
#       "mutato",
#       "appena",
#       "nome",
#       "livrea",
#       "hanno"
#     ],
#     [
#       "anno",
#       "xvn",
#       "cose",
#       "ora",
#       "francia",
#       "parigi",
#       "rao",
#       "villain",
#       "che",
#       "nel",
#       ...
#       "ventre",
#       "lorsignori",
#       "non",
#       "dovremo",
#       "aspettare",
#       "pezzo",
#       "bifolco",
#       "carlyle",
#       "french",
#       "revolution"
#     ]
#   ]

# %% [markdown]
# ### Outputs for step: ``remove_stopwords`` <a class="anchor" id="outputs_stage_1_remove_stopwords"></a>
#
# ### Output: ``token_list``
# #### Value metadata

# %%
step_remove_stopwords.output.token_list.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            0ddc97e1-54ec-40f0-a003-cad8ea9099b9                                      │
# │   type          array                                                                     │
# │   desc          An array of string lists, with the stopwords removed.                     │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_remove_stopwords.output.token_list.data)
# Out:
#
#   <pyarrow.lib.ListArray object at 0x7fd4566ca100>
#   [
#     [
#       "anno",
#       "xvn",
#       "heute",
#       "geht",
#       "neue",
#       "epoche",
#       "eltgescliighte",
#       "cuore",
#       "mondo",
#       "sveglia",
#       ...
#       "reclineranno",
#       "cervice",
#       "sotto",
#       "giogo",
#       "nuovi",
#       "mandriani",
#       "mutato",
#       "appena",
#       "nome",
#       "livrea"
#     ],
#     [
#       "anno",
#       "xvn",
#       "cose",
#       "ora",
#       "francia",
#       "parigi",
#       "rao",
#       "villain",
#       "gilia",
#       "guerra",
#       ...
#       "for",
#       "ventre",
#       "lorsignori",
#       "dovremo",
#       "aspettare",
#       "pezzo",
#       "bifolco",
#       "carlyle",
#       "french",
#       "revolution"
#     ]
#   ]

# %% [markdown]
# ### Outputs for step: ``lemmatize_corpus`` <a class="anchor" id="outputs_stage_1_lemmatize_corpus"></a>
#
# ### Output: ``tokens_array``
# #### Value metadata

# %%
step_lemmatize_corpus.output.tokens_array.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            c4df8e26-6611-42f9-b9f2-d859ea6baf8a                                      │
# │   type          array                                                                     │
# │   desc          An array of lists of lemmatized tokens.                                   │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_lemmatize_corpus.output.tokens_array.data)
# Out:
#
#   <pyarrow.lib.ListArray object at 0x7fd455a71ee0>
#   [
#     [
#       "anno",
#       "xvn",
#       "heute",
#       "geht",
#       "neue",
#       "epoca",
#       "eltgescliighte",
#       "cuore",
#       "mondare",
#       "sveglio",
#       ...
#       "reclinare",
#       "cervice",
#       "sotto",
#       "giogo",
#       "nuovo",
#       "mandriani",
#       "mutare",
#       "appena",
#       "nome",
#       "livrea"
#     ],
#     [
#       "anno",
#       "xvn",
#       "cosa",
#       "orare",
#       "francia",
#       "parigi",
#       "rao",
#       "villain",
#       "gilia",
#       "guerra",
#       ...
#       "for",
#       "ventre",
#       "lorsignori",
#       "dovere",
#       "aspettare",
#       "pezzo",
#       "bifolco",
#       "carlyle",
#       "french",
#       "revolution"
#     ]
#   ]

# %% [markdown]
# ### Outputs for step: ``generate_lda`` <a class="anchor" id="outputs_stage_1_generate_lda"></a>
#
# ### Output: ``topic_model``
# #### Value metadata

# %%
step_generate_lda.output.topic_model.value
# Out:
# ╭─ Value: n/a ──────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │   id            04174da7-cce7-4005-9343-77df34c879ac                                      │
# │   type          table                                                                     │
# │   desc          A table with 'topic_id' and 'words' columns (also 'num_topics', if        │
# │                 coherence calculation was switched on).                                   │
# │   is set        yes                                                                       │
# │   is constant   no                                                                        │
# │   hash          -- deferred --                                                            │
# │   metadata      -- no metadata --                                                         │
# │                                                                                           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### Value data

# %%
kiara.pretty_print(step_generate_lda.output.topic_model.data)
# Out:
#
#
#     topic_id   words                                                           num_topics
#    ───────────────────────────────────────────────────────────────────────────────────────
#     1          perchè, rivoluzione, guerra, ogni, primo, nuovo, stare,         3
#                sempre, repubblica, gove ...
#     2          primo, perchè, ogni, rivoluzione, guerra, stare, repubblica,    3
#                dovere, libertà, se ...
#     3          perchè, rivoluzione, ogni, guerra, primo, repubblica, stare,    3
#                governare, senza, n ...
#     1          ogni, rivoluzione, perchè, guerra, primo, nuovo, repubblica,    4
#                sempre, stare, tutt ...
#     2          rivoluzione, perchè, primo, ogni, stare, guerra, nuovo,         4
#                repubblica, sempre, qui, ...
#     3          perchè, rivoluzione, ogni, guerra, primo, dovere, sempre,       4
#                nuovo, senza, stare, r ...
#     4          perchè, rivoluzione, guerra, ogni, primo, stare, governare,     4
#                repubblica, senza, n ...
#     1          perchè, primo, rivoluzione, ogni, guerra, nuovo, stare,         5
#                sempre, tutto, repubblic ...
#     2          rivoluzione, perchè, primo, guerra, ogni, nuovo, stare,         5
#                senza, tutto, repubblica ...
#     3          rivoluzione, perchè, stare, primo, ogni, nuovo, guerra,         5
#                sempre, senza, germania, ...
#     4          perchè, rivoluzione, primo, guerra, ogni, repubblica, stare,    5
#                governare, vittoria ...
#     5          perchè, rivoluzione, ogni, guerra, primo, repubblica,           5
#                governare, stare, qui, ana ...
#     1          perchè, rivoluzione, guerra, ogni, primo, sempre, governare,    6
#                repubblica, vittori ...
#     2          rivoluzione, perchè, guerra, ogni, primo, repubblica, stare,    6
#                nuovo, vittoria, do ...
#     3          perchè, rivoluzione, ogni, primo, stare, nuovo, guerra,         6
#                senza, sempre, tutto, re ...
#     4          perchè, ogni, rivoluzione, repubblica, primo, guerra, stare,    6
#                qui, senza, libertà ...
#     ...        ...                                                             ...
#     4          perchè, ogni, rivoluzione, stare, guerra, dovere, primo, qui,   19
#                vittoria, repubbli ...
#     5          rivoluzione, perchè, primo, ogni, nuovo, bolsheviki, sempre,    19
#                guerra, senza, star ...
#     6          perchè, guerra, primo, ogni, rivoluzione, stare, dovere,        19
#                repubblica, governare,  ...
#     7          perchè, rivoluzione, ogni, sempre, nuovo, primo, stare,         19
#                tutto, guerra, libertà,  ...
#     8          perchè, guerra, repubblica, rivoluzione, ogni, primo, qui,      19
#                governare, sempre, st ...
#     9          rivoluzione, perchè, nuovo, primo, sempre, rivoluzionario,      19
#                stare, guerra, propri ...
#     10         perchè, primo, rivoluzione, senza, ogni, sempre, nuovo,         19
#                tutto, stare, germania,  ...
#     11         repubblica, guerra, perchè, vittoria, primo, stare, ogni,       19
#                rivoluzione, senza, go ...
#     12         perchè, rivoluzione, ogni, primo, guerra, repubblica, stare,    19
#                nuovo, vittoria, se ...
#     13         perchè, rivoluzione, guerra, ogni, stare, repubblica,           19
#                governare, dovere, qui, se ...
#     14         perchè, ogni, rivoluzione, primo, stare, guerra, governare,     19
#                sempre, repubblica,  ...
#     15         guerra, perchè, primo, ogni, rivoluzione, repubblica,           19
#                governare, mezzo, russia,  ...
#     16         perchè, rivoluzione, primo, nuovo, stare, ogni, sempre,         19
#                senza, guerra, germania, ...
#     17         perchè, rivoluzione, ogni, nuovo, guerra, primo, stare,         19
#                libertà, repubblica, bol ...
#     18         perchè, guerra, primo, rivoluzione, stare, repubblica, ogni,    19
#                qui, governare, sem ...
#     19         perchè, rivoluzione, ogni, primo, stare, guerra, repubblica,    19
#                sempre, anno, russi ...
